# %%
from sklearn import preprocessing

# %%
import sklearn
from sklearn import datasets
from sklearn import svm
from sklearn import metrics

# %%
import pandas 

df = pandas.read_csv('./data/processed/allSVD.csv' ) 
df
# Out:
#          Name         Type Tone Syllab               Jitter  \
# 0     743-u_n      healthy    n      u   1.1646918947469866
# 1      56-i_n      healthy    n      i  0.15539323315687034
# 2      39-a_l      healthy    l      a   0.2245756751722119
# 3      29-a_l      healthy    l      a   0.4988262635460537
# 4      46-i_n      healthy    n      i   0.5320076639389527
# ...       ...          ...  ...    ...                  ...
# 7806  151-a_l  psychogenic    l      a  0.10069827522321767
# 7807  366-u_n  psychogenic    n      u  0.20135621741415474
# 7808  741-a_h  psychogenic    h      a   0.2816129434012415
# 7809  366-u_l  psychogenic    l      u  0.38998106147144884
# 7810  151-a_n  psychogenic    n      a   0.4488633136165654
#
#                    Shimmer                 HNR              MFCC-0  \
# 0      0.04205820234169729   24.77275823210044  21.736318627254214
# 1     0.011061053912243473  26.922862501970428  23.644426247200997
# 2     0.027684195169233705    27.1517319166163  22.485759392633664
# 3      0.03885880149932715  20.022509683602063  22.026267355876595
# 4     0.023150390729872843  22.705092749924628  22.937200035479925
# ...                    ...                 ...                 ...
# 7806   0.01060182061650396  32.236174254178074  23.574362144860256
# 7807  0.015767262541399207  31.531413700838648   22.51136133401557
# 7808   0.02688210925571168  28.802297208678006  24.383547321705215
# 7809   0.03996580381546039  23.895286626051124  20.848472354253897
# 7810  0.024517452814006406  23.677346312386522  22.389438200345495
#
#                   MFCC-1               MFCC-2  ...            MFCC-2_d2  \
# 0     17.458523996774563    7.820948245411168  ...   0.7021405143591601
# 1     10.189441387513277    4.770981782206232  ...   0.4305431590261441
# 2       17.4170186138795    2.881102592313922  ...  0.26444503906900135
# 3     15.125505602724933   0.4576654479538485  ...  0.04769735759503534
# 4      8.484145255357388    6.262272207947027  ...    0.562402451832027
# ...                  ...                  ...  ...                  ...
# 7806   15.89206259009348  -2.1146196958090178  ...  -0.1793226530177768
# 7807  19.340193281695203     8.95412534359517  ...   0.7902882797550856
# 7808  15.528879597972022   1.1167965967649285  ...  0.10405877188217123
# 7809  14.195569412813464    5.796030724149894  ...   0.5184283360362505
# 7810  15.538401535128815   0.7915728360246284  ...  0.07555816992828945
#
#                  MFCC-3_d2              MFCC-4_d2             MFCC-5_d2  \
# 0       0.2707760894791415  -0.009504702040457442   -0.1282875639785897
# 1       0.5182585677890612    0.14392659213376907  -0.06273372712845295
# 2     -0.09145662377705228   -0.29231644409377977  -0.32855203157050056
# 3     -0.10755840659846741    -0.4098353863400703  -0.29708757445096196
# 4       0.6185424407938063    0.19518976044294545    -0.183319966297716
# ...                    ...                    ...                   ...
# 7806   -0.3699674965389807   -0.10808734389348357   0.10892831605898046
# 7807   0.16767651923040405   -0.15399946323996283   -0.1691007478547623
# 7808  -0.18631843258157976   -0.14654963311317246    0.0812140632737935
# 7809     0.280540355539336    0.10066103782587427    0.0364280047409229
# 7810  -0.16807337154555252  -0.052082022289533604   0.07700566986932122
#
#                  MFCC-6_d2             MFCC-7_d2              MFCC-8_d2  \
# 0     -0.18686289363010675  -0.08094209504851561   -0.10015773375157683
# 1       0.1270023355830291   0.04997587345193681   -0.08640876060694662
# 7806   -0.10808734389348357   0.10892831605898046   0.13544983543634034
# 7807   -0.15399946323996283   -0.1691007478547623  -0.16788417610769021
# 7808   -0.14654963311317246    0.0812140632737935   0.19714590679393504
# 7809    0.10066103782587427    0.0364280047409229  -0.02520961578931172
# 7810  -0.052082022289533604   0.07700566986932122    0.1662549596929822
#
#                  MFCC-7_d2              MFCC-8_d2              MFCC-9_d2  \
# 0     -0.08094209504851561   -0.10015773375157683  -0.020964215309692932
# 1      0.04997587345193681   -0.08640876060694662   0.016862483782557718
# 2     0.009097969162412069    -0.1912740154473819   0.004799002757619863
# 3      0.12302844779906943    0.11266385429440783     0.1759031794318167
# 4       0.1494429507088515   -0.21499785304149033  -0.022541550259250122
# ...                    ...                    ...                    ...
# 7806   0.08352047940332798    -0.1401604117438027   -0.11171766671048965
# 7807   0.03444342365659421    0.00444735240406489    0.01166488488299214
# 7808   0.14156748034506528   -0.09979350051546794    -0.1787731382756175
# 7809  0.028554209471496502   0.010087025707951586   0.016878616637454515
# 7810    0.2058158963576313  -0.042960416488819646   -0.01997170983747581
#
#                  MFCC-10_d2             MFCC-11_d2
# 0      -0.03432669525147786   -0.04588681708233835
# 1       -0.0802244828507097    0.00873499195351017
# 2      -0.08953871589344563    -0.0597190316618543
# 3      -0.13725585987216907   0.002435984759184925
# 4      -0.04795831792178612   -0.05946479442287478
# ...                     ...                    ...
# 7806  -0.050962049802496974   0.014015600504259639
# 7807   -0.03394872734761856   -0.11125000812770183
# 7808   -0.16544649033015257   -0.05425717095167515
# 7809  0.0014894039448345104  -0.045411153114880566
# 7810   -0.05908514058613632   -0.04028670810227334
#
# [7811 rows x 40 columns]>

# %%
# Create a label encoder object 
le = preprocessing.LabelEncoder()

# Fit the encoder object (le) to a pandas field with categorical data
le.fit(df['Type'])

# Display labels
target_names = list(le.classes_)
print(target_names)

# Apply the label encoder object to a pandas column
dys_target = le.transform(df['Type']) 
print(dys_target)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-3fe71dd74c63> in <module>
#       3
#       4 # Fit the encoder object (le) to a pandas field with categorical data
# ----> 5 le.fit(df['Type'])
#       6
#       7 # Display labels
#
# TypeError: 'method' object is not subscriptable

# %%
dys_data = df.drop(columns="Type").to_numpy()
dys_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6dce9504c540> in <module>
# ----> 1 dys_data = df.drop(columns="Type").to_numpy()
#       2 dys_data
#
# AttributeError: 'function' object has no attribute 'drop'

# %%
x = dys_data
y = dys_target

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.2)

# %%
clf = svm.SVC(kernel="linear", C=7)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
acc = metrics.accuracy_score(y_test, y_pred)
print("Linear Accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f59eeed43335> in <module>
#       1 clf = svm.SVC(kernel="linear", C=7)
# ----> 2 clf.fit(x_train, y_train)
#       3 y_pred = clf.predict(x_test)
#       4 acc = metrics.accuracy_score(y_test, y_pred)
#       5 print("Linear Accuracy:", acc)
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     158             check_consistent_length(X, y)
#     159         else:
# --> 160             X, y = self._validate_data(X, y, dtype=np.float64,
#     161                                        order='C', accept_sparse='csr',
#     162                                        accept_large_sparse=False)
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643
#     644         if force_all_finite:
# --> 645             _assert_all_finite(array,
#     646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      95                 not allow_nan and not np.isfinite(X).all()):
#      96             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 97             raise ValueError(
#      98                     msg_err.format
#      99                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
